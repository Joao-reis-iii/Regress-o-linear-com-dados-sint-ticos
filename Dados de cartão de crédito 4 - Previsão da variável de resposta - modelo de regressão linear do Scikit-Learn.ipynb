# %% [markdown]
# # PREVISÃO  DA VARIÁVEL DE RESPOSTA
#
# Regressão linear de dados sintéticos, equação linear com ruído gaussiano, com plotagem do gráfico de linha de regressão.
#
#
# -------------------
# Esta postagem interpreta e reproduz a estratégia de análise de Klosterman (2019).

# %% [markdown]
# Importação e checagem de versões das bibliotecas e pacotes

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib as mpl
import sklearn

print('The Python version is {}.\n'.format(sys.version))
print('The Numpy version is {}.\n'.format(np.__version__))
print('The Pandas version is {}.\n'.format(pd.__version__))
print('The Matplotlib version is {}.\n'.format(mpl.__version__))
print('The Scikit-Learn version is {}.\n'.format(sklearn.__version__))
# Out:
# The Python version is 3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)].
#
# The Numpy version is 1.20.1.
#
# The Pandas version is 1.2.4.
#
# The Matplotlib version is 3.3.4.
#
# The Scikit-Learn version is 0.24.1.

# %% [markdown]
# ________________________________
# A estratégia a seguir é de criação de dados sintéticos. Será criado um valor de resposta, com seed aleatório (dados sintéticos aleatórios criados pelo Numpy).
# Esses dados serão plotados. A modelagem será feita após esse procedimento.

# %%
np.random.seed(seed=1)
X = np.random.uniform(low=0.0, high=10.0, size=(1000,))
X[0:10]
# Out:
# array([4.17022005e+00, 7.20324493e+00, 1.14374817e-03, 3.02332573e+00,
#        1.46755891e+00, 9.23385948e-01, 1.86260211e+00, 3.45560727e+00,
#        3.96767474e+00, 5.38816734e+00])

# %% [raw]
# Será criado um array 1000 pontos de dados. A média do ruído (loc) será definida como 0 e desvio padrão (scale) 1

# %%
np.random.seed(seed=1)
slope = 0.25
intercept = -1.25
y = slope * X + np.random.normal(loc=0.0, scale=1.0, size=(1000,)) + intercept

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import matplotlib as mpl

# %%
mpl.rcParams['figure.dpi'] = 300

# %%
plt.scatter(X,y,s=1)

# %% [markdown]
# IMPORTAR E INSTANCIAR A CLASSE DE MODELO DE REGRESSÃO LINEAR DO SCIKIT-LEARN.
# A regressão linear - linha de melhor ajuste - será feita com os dados sintéticos criados acima.

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg
# Out:
# LinearRegression()

# %% [markdown]
# # Interceptação e inclinação da linha

# %%
lin_reg.fit(X.reshape(-1,1), y)
print(lin_reg.intercept_)
print(lin_reg.coef_)
# Out:
# -1.161256600282589
# [0.24002588]

# %%
y_pred = lin_reg.predict(X.reshape(-1,1))

# %%
plt.scatter(X,y,s=1)
plt.plot(X,y_pred,'r')
